# %% [markdown]
# # # Experiment:  RNN length=20, batch size=10, greedy_inc=0.001

# %%
from dqn_eval import Evaluator

eval = Evaluator(deque_window = 600)

# %%
eval.load_from_data()
print("overall_avg")
eval.plot(eval.overall_avg())
print("deque_avg")
eval.plot(eval.deque_avg())
print("deque_mid")
eval.plot(eval.deque_mid())
print("exp_moving_avg")
eval.plot(eval.exp_moving_avg())
# Out:
# overall_avg
# deque_avg
# deque_mid
# exp_moving_avg
