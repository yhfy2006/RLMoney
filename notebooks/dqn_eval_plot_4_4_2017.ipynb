# %% [markdown]
# # Experiment:  RNN length=50, batch size=20, greedy_inc=0.0005

# %%
import sys
import os
sys.path.append("..")
from dqn_eval import Evaluator

file = os.path.join(os.pardir, "data/dataLog")

eval = Evaluator(deque_window = 200,data_file=file)

# %%
eval.load_from_data()
print("overall_avg")
eval.plot(eval.overall_avg())
print("deque_avg")
eval.plot(eval.deque_avg())
print("deque_mid")
eval.plot(eval.deque_mid())
print("exp_moving_avg")
eval.plot(eval.exp_moving_avg())
print("sharp_ratio")
eval.plot(eval.sharpe_ratio())
# Out:
# overall_avg
# deque_avg
# deque_mid
# exp_moving_avg
# sharp_ratio
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-20-93142290ba6f> in <module>()
#       9 eval.plot(eval.exp_moving_avg())
#      10 print("sharp_ratio")
# ---> 11 eval.plot(eval.sharpe_ratio())
#
# /home/yhfy2006/RLMoney/dqn_eval.py in sharpe_ratio(self)
#      37         return_value = [(i-10000)/float(10000) for i in self.net_values_list]
#      38         return_value_std = self.net_stdev_list
# ---> 39         ratio = [return_value[i]/float(return_value_std[i]) for i in range(len(return_value))]
#      40         return ratio
#      41
#
# /home/yhfy2006/RLMoney/dqn_eval.py in <listcomp>(.0)
#      37         return_value = [(i-10000)/float(10000) for i in self.net_values_list]
#      38         return_value_std = self.net_stdev_list
# ---> 39         ratio = [return_value[i]/float(return_value_std[i]) for i in range(len(return_value))]
#      40         return ratio
#      41
#
# ZeroDivisionError: float division by zero
